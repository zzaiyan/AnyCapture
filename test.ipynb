# %%
from anycapture import get_local
get_local.activate()

# %%
import torch
import torch.nn as nn

class SimpleModel(nn.Module):
    def __init__(self):
        super(SimpleModel, self).__init__()
        self.linear = nn.Linear(10, 1)

    @get_local('x', 'out')
    def forward(self, x):
        out = self.linear(x)
        return out

# %%
dummy_input = torch.randn(5, 10)
model = SimpleModel()
with torch.no_grad():
    output = model(dummy_input)

# %%
get_local.cache
# Out:
# {'SimpleModel.forward.x': [array([[-1.9407779 , -0.2053033 ,  0.7880146 , -0.9371313 ,  0.77829766,
#           -0.08508534,  1.1213228 , -0.59124374,  0.44556248, -0.31536046],
#          [-1.0665869 ,  0.4006285 ,  0.06622906,  1.0655196 , -0.26297086,
#            0.32585627,  1.2208835 ,  1.1363908 ,  2.0933902 ,  0.9631917 ],
#          [ 0.77495587, -0.42061943, -0.74486417, -0.86577505, -0.71063966,
#           -1.1376402 ,  0.6915922 ,  1.2276487 ,  0.7079477 , -2.1255746 ],
#          [ 0.13129067, -0.32585758,  0.7745897 , -0.04291885, -0.03028769,
#           -0.645885  ,  0.7242089 , -0.25753647,  0.6680107 , -0.5723589 ],
#          [ 1.4991825 , -0.37609696, -0.25157765, -1.3020953 ,  0.05217697,
#           -0.83859175, -0.46390635,  0.44049504, -1.858013  , -0.9169908 ]],
#         dtype=float32)],
#  'SimpleModel.forward.out': [array([[-1.1560564 ],
#          [ 0.09091526],
#          [ 0.5851015 ],
#          [-0.39790258],
#          [ 0.8406467 ]], dtype=float32)]}
